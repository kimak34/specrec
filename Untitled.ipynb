# %%
# %run -i "config.py"
# Out:
# C:\Users\kwens\Anaconda3\envs\py311\Lib\site-packages\librosa\util\decorators.py:88: UserWarning: PySoundFile failed. Trying audioread instead.
#   return f(*args, **kwargs)
# Loading audio:  9.309593200683594
# Getting random samples:  0.003020763397216797
# Getting spectrogram:  0.923969030380249
# Getting peaks:  0.8209304809570312
# Getting fingerprints:  0.23134803771972656
# Storing all fingerprint:  0.21146941184997559
# Getting spectrogram:  0.9418966770172119
# Getting peaks:  0.4568004608154297
# Getting fingerprints:  0.21639537811279297
# Storing all fingerprint:  0.05185747146606445
# Getting spectrogram:  0.9342730045318604
# Getting peaks:  0.45578885078430176
# Getting fingerprints:  0.2296137809753418
# Storing all fingerprint:  0.046286582946777344
# Getting spectrogram:  0.9570231437683105
# Getting peaks:  0.4398162364959717
# Getting fingerprints:  0.2204151153564453
# Storing all fingerprint:  0.0498661994934082
# Getting spectrogram:  0.9739420413970947
# ...

# %%
# %run -i "config.py"
# Out:
# C:\Users\kwens\Anaconda3\envs\py311\Lib\site-packages\librosa\util\decorators.py:88: UserWarning: PySoundFile failed. Trying audioread instead.
#   return f(*args, **kwargs)
# C:\Users\kwens\Anaconda3\envs\py311\Lib\site-packages\librosa\util\decorators.py:88: UserWarning: PySoundFile failed. Trying audioread instead.
#   return f(*args, **kwargs)

# %%
import database_utils
database_utils.load_database("database")
# Out:
# {(64.599609375,
#   829.0283203125,
#   0.37151927437641724): [(0, 0.046439909297052155), (0,
#    0.046439909297052155), (0, 0.046439909297052155), (0,
#    0.046439909297052155), (0, 0.046439909297052155)],
#  (64.599609375, 2928.515625, 0.882358276643991): [(0, 0.046439909297052155),
#   (0, 0.046439909297052155),
#   (0, 0.046439909297052155),
#   (0, 0.046439909297052155),
#   (0, 0.046439909297052155)],
#  (64.599609375, 3574.51171875, 0.882358276643991): [(0, 0.046439909297052155),
#   (0, 0.046439909297052155),
#   (0, 0.046439909297052155),
#   (0, 0.046439909297052155),
#   (0, 0.046439909297052155)],
#  (64.599609375,
#   3929.8095703125,
#   0.882358276643991): [(0, 0.046439909297052155), (0,
#    0.046439909297052155), (0, 0.046439909297052155), (0,
#    0.046439909297052155), (0, 0.046439909297052155)],
#  (64.599609375, 4198.974609375, 0.882358276643991): [(0, 0.046439909297052155),
#   (0, 0.046439909297052155),
#   (0, 0.046439909297052155),
# ...

# %%
# %run -i "main.py"
# Out:
# Please input what ('mic' or 'file') you want to record ("q" to quit): mic
# How long would you like to record for: 5
# Using input device 'Microsoft Sound Mapper - Input'
# Recording ended
# The song that matches this is Eine Kleine Nachtmusik by Wolfgang Amadeus Mozart.
# Please input what ('mic' or 'file') you want to record ("q" to quit): mic
# How long would you like to record for: 5
# Using input device 'Microsoft Sound Mapper - Input'
# Recording ended
# The song that matches this is Die For You by The Weeknd.
# Please input what ('mic' or 'file') you want to record ("q" to quit): mic
# How long would you like to record for: 5
# Using input device 'Microsoft Sound Mapper - Input'
# Recording ended
# The song that matches this is Eine Kleine Nachtmusik by Wolfgang Amadeus Mozart.
# Please input what ('mic' or 'file') you want to record ("q" to quit): q

# %%
from microphone import record_audio
record_audio(5)
# Out:
# Using input device 'Microsoft Sound Mapper - Input'
# Recording ended
# ...

# %%
from collections import defaultdict

# %%
max(defaultdict(int).values())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 max(defaultdict(int).values())
#
# ValueError: max() arg is an empty sequence
